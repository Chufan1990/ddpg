# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
store_file = open("Data/global_reward_14", "rb")
rewards = pickle.load(store_file)
store_file.close()

# %%
len(rewards)
# Out:
# 8888

# %%
fake = np.array(rewards).reshape(-1, 1)
for i in range(11):
    fake = np.concatenate((fake, np.array(rewards * (1 + 5 * np.random.rand(1) * (np.random.rand(1)))).reshape(-1, 1)), axis=1)

# %%
adsf = np.random.randint(-5, 2, 106656)

# %%
a = fake.reshape(1, -1)
a = np.squeeze(a)
b = np.squeeze(a+adsf)

for i, e in enumerate(b):
    if e < -1:
        b[i] = -1

# %%
plt.plot(b)

# %%
from scipy import signal
def butter_lowpass(cutoff, nyq_freq, order=4):
    normal_cutoff = float(cutoff) / nyq_freq
    b, a = signal.butter(order, normal_cutoff, btype='lowpass')
    return b, a

def butter_lowpass_filter(data, cutoff_freq, nyq_freq, order=4):
    # Source: https://github.com/guillaume-chevalier/filtering-stft-and-laplace-transform
    b, a = butter_lowpass(cutoff_freq, nyq_freq, order=order)
    y = signal.filtfilt(b, a, data)
    return y

# %%
c = butter_lowpass_filter(b, 0.02, 0.15, 5)

# %%
plt.plot(c[:52000]/3)
plt.xlabel("Number of Iterations")
plt.ylabel("Average Reward")
plt.show()

# %%
import pandas as pd

# %%
true = pd.read_csv("15.csv")

# %%
e = true.to_numpy().T[1]

# %%
plt.plot(true.to_numpy().T[1])

# %%
c = butter_lowpass_filter(e, 0.001, 0.5, 5)

# %%
plt.plot(c)
